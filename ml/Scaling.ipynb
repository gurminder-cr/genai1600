# %%
import pandas as pd

# %%
df=pd.DataFrame({'Marks':[23,26,29,45,100,130,150,190,550,54,32,11,9,56,900]})
df
# Out:
#     Marks
# 0      23
# 1      26
# 2      29
# 3      45
# 4     100
# 5     130
# 6     150
# 7     190
# 8     550
# 9      54
# 10     32
# 11     11
# 12      9
# 13     56
# 14    900

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
minmax=MinMaxScaler(feature_range=(0, 5))

# %% [markdown]
# X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))
# X_scaled = X_std * (max - min) + min

# %%
minmax.fit_transform(df.loc[:,['Marks']])
# Out:
# array([[0.07856341],
#        [0.09539843],
#        [0.11223345],
#        [0.2020202 ],
#        [0.51066218],
#        [0.67901235],
#        [0.79124579],
#        [1.01571268],
#        [3.0359147 ],
#        [0.25252525],
#        [0.12906846],
#        [0.01122334],
#        [0.        ],
#        [0.2637486 ],
#        [5.        ]])

# %%
std_scaler =  StandardScaler()
# z = (x - u) / s

# %%
std_scaler.fit_transform(df.loc[:,['Marks']])
# Out:
# array([[-0.54725529],
#        [-0.53469076],
#        [-0.52212622],
#        [-0.45511537],
#        [-0.22476557],
#        [-0.09912022],
#        [-0.01535665],
#        [ 0.15217048],
#        [ 1.65991464],
#        [-0.41742177],
#        [-0.50956169],
#        [-0.59751343],
#        [-0.60588979],
#        [-0.40904541],
#        [ 3.12577703]])

# %% [markdown]
# MinMaxScaler is used when a fixed, bounded range is required for the data, or when the data distribution is not normal. StandardScaler is typically preferred for algorithms that assume a normal distribution or are sensitive to variance
