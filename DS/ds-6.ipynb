# %%
import pandas as pd

# %%
d= pd.DataFrame([[1,2,3,4],[4,5,6,7],[1,2,3,4],[5,43,21,1]])
d
# Out:
#    0   1   2  3
# 0  1   2   3  4
# 1  4   5   6  7
# 2  1   2   3  4
# 3  5  43  21  1

# %%
d.drop_duplicates()
# Out:
#    0   1   2  3
# 0  1   2   3  4
# 1  4   5   6  7
# 3  5  43  21  1

# %%
# data= pd.read_csv('Titanic-Dataset.csv')
# data.head()

# seaborn
# pip install seaborn - in cmd 
import seaborn as sns 
data= sns.load_dataset('titanic')
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data.drop('deck', inplace=True, axis=1)

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data[data.age.isnull()]
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 5           0       3    male  NaN      0      0   8.4583        Q   Third
# 17          1       2    male  NaN      0      0  13.0000        S  Second
# 19          1       3  female  NaN      0      0   7.2250        C   Third
# 26          0       3    male  NaN      0      0   7.2250        C   Third
# 28          1       3  female  NaN      0      0   7.8792        Q   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 859         0       3    male  NaN      0      0   7.2292        C   Third
# 863         0       3  female  NaN      8      2  69.5500        S   Third
# 868         0       3    male  NaN      0      0   9.5000        S   Third
# 878         0       3    male  NaN      0      0   7.8958        S   Third
# 888         0       3  female  NaN      1      2  23.4500        S   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
data.age.min()
# Out:
# 0.42

# %%
data.age.max()
# Out:
# 80.0

# %%
data.age.mean()
# Out:
# 29.69911764705882

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
data.who.value_counts()
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %%
data_man= data[data.loc[:,'who']=='man']

# %%
data_man.shape
# Out:
# (537, 14)

# %%
data_man[data_man.age.isnull()]
# Out:
#      survived  pclass   sex  age  sibsp  parch     fare embarked   class  who  \
# 5           0       3  male  NaN      0      0   8.4583        Q   Third  man
# 17          1       2  male  NaN      0      0  13.0000        S  Second  man
# 26          0       3  male  NaN      0      0   7.2250        C   Third  man
# 29          0       3  male  NaN      0      0   7.8958        S   Third  man
# 36          1       3  male  NaN      0      0   7.2292        C   Third  man
# ..        ...     ...   ...  ...    ...    ...      ...      ...     ...  ...
# 839         1       1  male  NaN      0      0  29.7000        C   First  man
# 846         0       3  male  NaN      8      2  69.5500        S   Third  man
# 859         0       3  male  NaN      0      0   7.2292        C   Third  man
# 868         0       3  male  NaN      0      0   9.5000        S   Third  man
# 878         0       3  male  NaN      0      0   7.8958        S   Third  man
#
# ...

# %%
data_man_agemean=data_man.age.mean()
data_man_agemean
# Out:
# 33.17312348668281

# %%
man_index= data_man[data_man.age.isnull()].index

# %%
man_index
# Out:
# Index([  5,  17,  26,  29,  36,  42,  45,  46,  48,  55,
#        ...
#        825, 826, 828, 832, 837, 839, 846, 859, 868, 878],
#       dtype='int64', length=124)

# %%
data.loc[man_index,'age']=data_man_agemean

# %%
data.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age            53
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %%
data_woman= data[data.loc[:,'who']=='woman']
data_woman
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
woman_index= data_woman[data_woman.age.isnull()].index

# %%
woman_index
# Out:
# Index([ 19,  28,  31,  32,  47,  82, 109, 128, 140, 166, 180, 186, 198, 229,
#        235, 240, 241, 256, 264, 274, 300, 303, 306, 330, 334, 347, 358, 359,
#        367, 368, 375, 409, 415, 431, 457, 485, 502, 533, 564, 573, 578, 593,
#        596, 612, 653, 669, 680, 697, 727, 792, 849, 863, 888],
#       dtype='int64')

# %%
data_woman.age.mean()
# Out:
# 32.0

# %%
data.loc[woman_index,'age']=data_woman.age.mean()

# %%
data.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
df= pd.read_csv('2023_Countries by Population.csv')
df
# Out:
#      place      pop1980       pop2000       pop2010       pop2022  \
# 0      356  696828385.0  1.059634e+09  1.240614e+09  1.417173e+09
# 1      156  982372466.0  1.264099e+09  1.348191e+09  1.425887e+09
# 2      840  223140018.0  2.823986e+08  3.111828e+08  3.382899e+08
# 3      360  148177096.0  2.140724e+08  2.440162e+08  2.755013e+08
# 4      586   80624057.0  1.543699e+08  1.944545e+08  2.358249e+08
# ..     ...          ...           ...           ...           ...
# 229    500      11452.0  5.138000e+03  4.938000e+03  4.390000e+03
# 230    238       2240.0  3.080000e+03  3.187000e+03  3.780000e+03
# 231    570       3637.0  2.074000e+03  1.812000e+03  1.934000e+03
# 232    772       1647.0  1.666000e+03  1.367000e+03  1.871000e+03
# 233    336        733.0  6.510000e+02  5.960000e+02  5.100000e+02
#
#           pop2023       pop2030       pop2050           country        area  \
# 0    1.428628e+09  1.514994e+09  1.670491e+09             India  3287590.00
# ...

# %%
a= df.loc[:,'pop2023']*df.loc[:,'growthRate']
a= a*2

# %%
value= df.loc[:,'pop2023']+a

# %%
df.insert(6,column='pop2025', value=value)

# %%
df
# Out:
#      place      pop1980       pop2000       pop2010       pop2022  \
# 0      356  696828385.0  1.059634e+09  1.240614e+09  1.417173e+09
# 1      156  982372466.0  1.264099e+09  1.348191e+09  1.425887e+09
# 2      840  223140018.0  2.823986e+08  3.111828e+08  3.382899e+08
# 3      360  148177096.0  2.140724e+08  2.440162e+08  2.755013e+08
# 4      586   80624057.0  1.543699e+08  1.944545e+08  2.358249e+08
# ..     ...          ...           ...           ...           ...
# 229    500      11452.0  5.138000e+03  4.938000e+03  4.390000e+03
# 230    238       2240.0  3.080000e+03  3.187000e+03  3.780000e+03
# 231    570       3637.0  2.074000e+03  1.812000e+03  1.934000e+03
# 232    772       1647.0  1.666000e+03  1.367000e+03  1.871000e+03
# 233    336        733.0  6.510000e+02  5.960000e+02  5.100000e+02
#
#           pop2023       pop2025       pop2030       pop2050           country  \
# 0    1.428628e+09  1.451771e+09  1.514994e+09  1.670491e+09             India
# ...

# %%
df.loc[:,'pop2023']- (df.loc[:,'pop2023']*df.loc[:,'growthRate'])
# Out:
# 0      1.417056e+09
# 1      1.425956e+09
# 2      3.382966e+08
# 3      2.754804e+08
# 4      2.357240e+08
#            ...
# 229    4.389947e+03
# 230    3.780006e+03
# 231    1.934033e+03
# 232    1.870663e+03
# 233    5.098674e+02
# Length: 234, dtype: float64

# %%
df.isnull().sum()
# Out:
# place              0
# pop1980            0
# pop2000            0
# pop2010            0
# pop2022            0
# pop2023            0
# pop2025            0
# pop2030            0
# pop2050            0
# country            0
# area               0
# landAreaKm         0
# cca2               1
# cca3               0
# netChange          8
# growthRate         0
# worldPercentage    6
# density            0
# densityMi          0
# rank               0
# dtype: int64
