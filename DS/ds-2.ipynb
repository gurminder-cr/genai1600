# %%
import pandas as pd
ser= pd.Series([34,33,21,100,45,67,10])
ser
# Out:
# 0     34
# 1     33
# 2     21
# 3    100
# 4     45
# 5     67
# 6     10
# dtype: int64

# %%
serd= pd.Series({'a':12,'b':44,'c':10})
serd
# Out:
# a    12
# b    44
# c    10
# dtype: int64

# %%
serd= pd.Series({'a':12,'b':44,'c':10},index=['a','b'])
serd
# Out:
# a    12
# b    44
# dtype: int64

# %%
ser
# Out:
# 0     34
# 1     33
# 2     21
# 3    100
# 4     45
# 5     67
# 6     10
# dtype: int64

# %%
ser.shape
# Out:
# (7,)

# %%
ser.max()
# Out:
# 100

# %%
ser.min()
# Out:
# 10

# %%
ser.idxmax() # index of maximum value
# Out:
# 3

# %%
ser.idxmin()  # index of minimum value
# Out:
# 6

# %%
ser.sum()
# Out:
# 310

# %%
ser.mean()
# Out:
# 44.285714285714285

# %%
ser.mode()
# Out:
# 0     10
# 1     21
# 2     33
# 3     34
# 4     45
# 5     67
# 6    100
# dtype: int64

# %%
ser.median()
# Out:
# 34.0

# %%
# update, add
ser
# Out:
# 0     34
# 1     33
# 2     21
# 3    100
# 4     45
# 5     67
# 6     10
# dtype: int64

# %%
ser[2]=125

# %%
ser
# Out:
# 0     34
# 1     33
# 2    125
# 3    100
# 4     45
# 5     67
# 6     10
# dtype: int64

# %%
ser[8]=50

# %%
ser
# Out:
# 0     34
# 1     33
# 2    125
# 3    100
# 4     45
# 5     67
# 6     10
# 8     50
# dtype: int64

# %%
serd['l']=200

# %%
serd
# Out:
# a     12
# b     44
# l    200
# dtype: int64

# %%
ser[:2]=100

# %%
ser
# Out:
# 0    100
# 1    100
# 2    125
# 3    100
# 4     45
# 5     67
# 6     10
# 8     50
# dtype: int64

# %%
# delete - drop
ser.drop(8)
# Out:
# 0    100
# 1    100
# 2    125
# 3    100
# 4     45
# 5     67
# 6     10
# dtype: int64

# %%
ser.drop(8,inplace=True)

# %%
ser
# Out:
# 0    100
# 1    100
# 2    125
# 3    100
# 4     45
# 5     67
# 6     10
# dtype: int64

# %%
# null values 

ser1= pd.Series([23,None,100,None,34,None,20,91])
ser1
# Out:
# 0     23.0
# 1      NaN
# 2    100.0
# 3      NaN
# 4     34.0
# 5      NaN
# 6     20.0
# 7     91.0
# dtype: float64

# %%
ser1
# Out:
# 0     23.0
# 1      NaN
# 2    100.0
# 3      NaN
# 4     34.0
# 5      NaN
# 6     20.0
# 7     91.0
# dtype: float64

# %%
ser1[1]=10
ser1
# Out:
# 0     23.0
# 1     10.0
# 2    100.0
# 3      NaN
# 4     34.0
# 5      NaN
# 6     20.0
# 7     91.0
# dtype: float64

# %%
ser1.mean()
# Out:
# 46.333333333333336

# %%
ser1.fillna(ser1.mean(), inplace=True)

# %%
ser1
# Out:
# 0     23.000000
# 1     10.000000
# 2    100.000000
# 3     46.333333
# 4     34.000000
# 5     46.333333
# 6     20.000000
# 7     91.000000
# dtype: float64

# %%
# null values 

ser1= pd.Series([23,None,100,None,34,None,20,91])
ser1
# Out:
# 0     23.0
# 1      NaN
# 2    100.0
# 3      NaN
# 4     34.0
# 5      NaN
# 6     20.0
# 7     91.0
# dtype: float64

# %%
ser1.dropna()
# Out:
# 0     23.0
# 2    100.0
# 4     34.0
# 6     20.0
# 7     91.0
# dtype: float64

# %%
ser1.dropna(ignore_index=True)
# Out:
# 0     23.0
# 1    100.0
# 2     34.0
# 3     20.0
# 4     91.0
# dtype: float64

# %%
ser1
# Out:
# 0     23.0
# 1      NaN
# 2    100.0
# 3      NaN
# 4     34.0
# 5      NaN
# 6     20.0
# 7     91.0
# dtype: float64
