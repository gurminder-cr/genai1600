# %% [markdown]
# <p style='text-align:center'>
# pip install notebook
# after installation--- in cmd --> jupyter notebook
# or
# python -m notebook
# </p>

# %% [markdown]
# # heading 1
# ## heading 2
#  upto6
# ###### heading 6

# %% [markdown]
# ![image.png](attachment:c03b9116-f407-4322-8878-5ce42a9cc78c.png)

# %% [raw]
# print("Hi")

# %%
print("Hello")
# Out:
# Hello

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
a
b
# Out:
# 20

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# pip install pandas -
# data cleaning, transformation, wrangling 
import pandas as pd

# %%
a=20

# %%
print(a)
# Out:
# 15

# %%
b=20
a+b
# Out:
# 40

# %%
# Data Science - Pandas 
# 1d, 2d 
# series, dataframe

# Series- list, dictionary

s= pd.Series([10,12,44,33,14,54])
s
# Out:
# 0    10
# 1    12
# 2    44
# 3    33
# 4    14
# 5    54
# dtype: int64

# %%
s1=pd.Series([34,True,'hello',100,6.54])
s1
# Out:
# 0       34
# 1     True
# 2    hello
# 3      100
# 4     6.54
# dtype: object

# %%
s1=pd.Series(data=[34,True,'hello',100,6.54],index=['a','b','c','d','e'])

# %%
s1
# Out:
# a       34
# b     True
# c    hello
# d      100
# e     6.54
# dtype: object

# %%
s2= pd.Series([i**2 for i in range(0,20)], index=[i for i in range(0,20)])

# %%
s2
# Out:
# 0       0
# 1       1
# 2       4
# 3       9
# 4      16
# 5      25
# 6      36
# 7      49
# 8      64
# 9      81
# 10    100
# 11    121
# 12    144
# 13    169
# 14    196
# 15    225
# 16    256
# 17    289
# 18    324
# 19    361
# dtype: int64

# %%
s1
# Out:
# a       34
# b     True
# c    hello
# d      100
# e     6.54
# dtype: object

# %%
s
# Out:
# 0    10
# 1    12
# 2    44
# 3    33
# 4    14
# 5    54
# dtype: int64

# %%
s.head(2) # by default first 5
# Out:
# 0    10
# 1    12
# dtype: int64

# %%
s.tail(3)# by default last 5
# Out:
# 3    33
# 4    14
# 5    54
# dtype: int64

# %%
s.shape
# Out:
# (6,)

# %%
s2.shape
# Out:
# (20,)

# %%
# access values  [], .
s[:2]
# Out:
# 0    10
# 1    12
# dtype: int64

# %%
s1[:3]
# Out:
# a       34
# b     True
# c    hello
# dtype: object

# %%
s1.a
# Out:
# 34

# %%
s1['a':'d']
# Out:
# a       34
# b     True
# c    hello
# d      100
# dtype: object

# %%
s[1:4]
# Out:
# 1    12
# 2    44
# 3    33
# dtype: int64

# %%
s1.b  #dot de naal hamesha string index hi use hoyyega
# Out:
# True

# %%
# loc, iloc  # loc - location for labels, index location for indexes

# %%
s
# Out:
# 0    10
# 1    12
# 2    44
# 3    33
# 4    14
# 5    54
# dtype: int64

# %%
s.loc[:2]
# Out:
# 0    10
# 1    12
# 2    44
# dtype: int64

# %%
s.iloc[:2]
# Out:
# 0    10
# 1    12
# dtype: int64

# %%
s1
# Out:
# a       34
# b     True
# c    hello
# d      100
# e     6.54
# dtype: object

# %%
s1.loc[:'c']
# Out:
# a       34
# b     True
# c    hello
# dtype: object

# %%
s1.iloc[:2]
# Out:
# a      34
# b    True
# dtype: object

# %%
# conditions

# %%
s2
# Out:
# 0       0
# 1       1
# 2       4
# 3       9
# 4      16
# 5      25
# 6      36
# 7      49
# 8      64
# 9      81
# 10    100
# 11    121
# 12    144
# 13    169
# 14    196
# 15    225
# 16    256
# 17    289
# 18    324
# 19    361
# dtype: int64

# %%
s
# Out:
# 0    10
# 1    12
# 2    44
# 3    33
# 4    14
# 5    54
# dtype: int64

# %%
s>15
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
s[s>15]
# Out:
# 2    44
# 3    33
# 5    54
# dtype: int64

# %%
s[(s>15) & (s<50)]
# Out:
# 2    44
# 3    33
# dtype: int64

# %%
s[s.between(15,50, inclusive='left')]
# Out:
# 2    44
# 3    33
# dtype: int64

# %%
# 
s[s==14]
# Out:
# 4    14
# dtype: int64

# %%
# isin 
s[s.isin([14])]
# Out:
# 4    14
# dtype: int64

# %%
names=['A','B','C','D']
scores=[45,78,90,60]

for i,j in enumerate(zip(names, scores)):
    print(i,"-",j[0],"Scored",j[1])
# Out:
# 0 - A Scored 45
# 1 - B Scored 78
# 2 - C Scored 90
# 3 - D Scored 60
