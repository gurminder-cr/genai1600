# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# histograms
data = [32, 96, 45, 67, 76, 28, 79, 62, 43, 81, 70,61, 95, 44, 60, 69, 71, 23
       ,69, 54, 76, 67,82, 97, 26, 34, 18, 16, 59, 88, 29, 30, 66,23, 65, 72, 
       20, 78, 49, 73, 62, 87, 37, 68,81, 80, 77, 92, 81, 52, 43, 68, 71, 86]
plt.hist(data)
plt.show()

# %%
import plotly.express as px
# pip install plotly-express 

px.histogram(data)

# %%
titanic= sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.loc[:,'class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
sns.countplot(data=titanic, x='class')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
a= sns.countplot(data=titanic, x='class')
a.set_title('Count of Passengers vs class')
a.set_xlabel('Classes')
a.set_ylabel('Count of Passengers')
a.set_xticklabels(['1st','2nd','3rd'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_22500\3804770381.py:5: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# [Text(0, 0, '1st'), Text(1, 0, '2nd'), Text(2, 0, '3rd')]

# %%
sns.histplot(data)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd

# %%
# funnel chart 
d= pd.DataFrame({'number':[39, 27.4, 20.6, 11, 2],'stage':["Website visit", "Downloads", "Potential customers", "Requested price", "invoice sent"]})

# %%
d
# Out:
#    number                stage
# 0    39.0        Website visit
# 1    27.4            Downloads
# 2    20.6  Potential customers
# 3    11.0      Requested price
# 4     2.0         invoice sent

# %%
px.funnel(data_frame=d, x='number',y='stage')

# %%
px.pie(data_frame=d, values='number',labels='stage')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.who.value_counts()
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %%
titanic.who.value_counts().index
# Out:
# Index(['man', 'woman', 'child'], dtype='object', name='who')

# %%
titanic.who.value_counts().values
# Out:
# array([537, 271,  83], dtype=int64)

# %%
px.pie(values=titanic.who.value_counts().values, labels=titanic.who.value_counts().index )

# %%
tips= sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
px.pie(data_frame=tips, values='tip',names='smoker', color='sex')

# %%
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species",
                 size='sepal_width')
fig.show()

# %%
# Box plot 
# IQR - inter quartile range - Q3-Q1 
# Lower fence and higher fence 

d=[23,24,29,30,43,45,49,120,130]
px.box(d)
