# %%
import pandas as pd
df= pd.DataFrame({'Name':['Aryan','Vasu','Jasbir','Prachi','Sham','Raaju'],'Rollno':[12,34,33,21,10,34], 'class':['Bca','Mba','bba','bba','btech','btech']})
df
# Out:
#      Name  Rollno  class
# 0   Aryan      12    Bca
# 1    Vasu      34    Mba
# 2  Jasbir      33    bba
# 3  Prachi      21    bba
# 4    Sham      10  btech
# 5   Raaju      34  btech

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Rollno  6 non-null      int64
#  2   class   6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 276.0+ bytes

# %%
df.loc[:,'class']=df.loc[:,'class'].str.upper()

# %%
df
# Out:
#      Name  Rollno  class
# 0   Aryan      12    BCA
# 1    Vasu      34    MBA
# 2  Jasbir      33    BBA
# 3  Prachi      21    BBA
# 4    Sham      10  BTECH
# 5   Raaju      34  BTECH

# %%
df.Rollno= df.Rollno.astype('str')

# %%
df.Rollno.dtype
# Out:
# dtype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Rollno  6 non-null      object
#  2   class   6 non-null      object
# dtypes: object(3)
# memory usage: 276.0+ bytes

# %%
# map, apply_map 
df.applymap(lambda x: x+"hi")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17972\4056939485.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x+"hi")
#        Name Rollno    class
# 0   Aryanhi   12hi    BCAhi
# 1    Vasuhi   34hi    MBAhi
# 2  Jasbirhi   33hi    BBAhi
# 3  Prachihi   21hi    BBAhi
# 4    Shamhi   10hi  BTECHhi
# 5   Raajuhi   34hi  BTECHhi

# %%
t= pd.read_csv('Titanic-Dataset.csv')
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t.loc[:,'Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
t.loc[:,'Sex'].map({'male':0,'female':1})
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: Sex, Length: 891, dtype: int64

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df
# Out:
#      Name Rollno  class
# 0   Aryan     12    BCA
# 1    Vasu     34    MBA
# 2  Jasbir     33    BBA
# 3  Prachi     21    BBA
# 4    Sham     10  BTECH
# 5   Raaju     34  BTECH

# %%
df.rename(columns={'class':'Degree'}, inplace=True) # old:new

# %%
df
# Out:
#      Name Rollno Degree
# 0   Aryan     12    BCA
# 1    Vasu     34    MBA
# 2  Jasbir     33    BBA
# 3  Prachi     21    BBA
# 4    Sham     10  BTECH
# 5   Raaju     34  BTECH
