# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
import seaborn as sns
import plotly.express as px 
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('zomato_dataset.csv')
df.head()
# Out:
#   Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0      Doner King            3.9              4.2            39
# 1      Doner King            3.9              4.2            39
# 2      Doner King            3.9              4.2            39
# 3      Doner King            3.9              4.2            39
# 4      Doner King            3.9              4.2            39
#
#    Delivery Votes   Cuisine  Place Name        City                 Item Name  \
# 0               0  Fast Food   Malakpet   Hyderabad       Platter Kebab Combo
# 1               0  Fast Food   Malakpet   Hyderabad   Chicken Rumali Shawarma
# 2               0  Fast Food   Malakpet   Hyderabad    Chicken Tandoori Salad
# 3               0  Fast Food   Malakpet   Hyderabad         Chicken BBQ Salad
# 4               0  Fast Food   Malakpet   Hyderabad  Special Doner Wrap Combo
#
#   Best Seller  Votes  Prices
# 0  BESTSELLER     84   249.0
# 1  BESTSELLER     45   129.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123657 entries, 0 to 123656
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Restaurant Name  123657 non-null  object
#  1   Dining Rating    91421 non-null   float64
#  2   Delivery Rating  122377 non-null  float64
#  3   Dining Votes     123657 non-null  int64
#  4   Delivery Votes   123657 non-null  int64
#  5   Cuisine          123657 non-null  object
#  6   Place Name       123657 non-null  object
#  7   City             123657 non-null  object
#  8   Item Name        123657 non-null  object
#  9   Best Seller      27942 non-null   object
#  10  Votes            123657 non-null  int64
#  11  Prices           123657 non-null  float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 11.3+ MB

# %%
df.isnull().sum()
# Out:
# Restaurant Name        0
# Dining Rating      32236
# Delivery Rating     1280
# Dining Votes           0
# Delivery Votes         0
# Cuisine                0
# Place Name             0
# City                   0
# Item Name              0
# Best Seller        95715
# Votes                  0
# Prices                 0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (20228, 12)

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (13537, 12)

# %%
df
# Out:
#               Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0                  Doner King            3.9              4.2            39
# 1                  Doner King            3.9              4.2            39
# 3                  Doner King            3.9              4.2            39
# 4                  Doner King            3.9              4.2            39
# 5                  Doner King            3.9              4.2            39
# ...                       ...            ...              ...           ...
# 123586  Ariena Boutique Hotel            3.9              4.2            13
# 123594  Ariena Boutique Hotel            3.9              4.2            13
# 123603  Ariena Boutique Hotel            3.9              4.2            13
# 123605  Ariena Boutique Hotel            3.9              4.2            13
# 123635  Ariena Boutique Hotel            3.9              4.2            13
#
# ...

# %%
# df.loc[:,'Restaurant Name'].value_counts()
index_top= df.loc[:,'Restaurant Name'].value_counts().index

# %%
index_top[:5]
# Out:
# Index(['Pizza Hut', 'McDonald's', 'Domino's Pizza', 'HSR High Street',
#        'Toscano'],
#       dtype='object', name='Restaurant Name')

# %%
value_top= df.loc[:,'Restaurant Name'].value_counts().values

# %%
value_top[:5]
# Out:
# array([352, 320, 287, 216, 170], dtype=int64)

# %%
px.pie(names=index_top[:5], values=value_top[:5], title="Highest Order vs Restaurant Name")

# %%
d= df.sort_values(by='Votes', ascending=False)

# %%
d
# Out:
#         Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 12417            Mehfil            4.1              4.0             0
# 11146          Bawarchi            4.2              4.1             0
# 6135   Lucky Restaurant            4.1              4.0             0
# 11145          Bawarchi            4.2              4.1             0
# 12416            Mehfil            4.1              4.0             0
# ...                 ...            ...              ...           ...
# 41255  Mother's Kitchen            4.1              3.9            93
# 87074   New Freeze Land            4.2              4.1           896
# 87067   New Freeze Land            4.2              4.1           896
# 41256  Mother's Kitchen            4.1              3.9            93
# 67625       Chinese Wok            3.3              4.0             2
#
#        Delivery Votes      Cuisine     Place Name        City  \
# 12417               0  North Indian   Narayanguda   Hyderabad
# ...

# %%
px.bar(data_frame=d[:10], x='Restaurant Name',y='Votes')

# %%
df
# Out:
#               Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0                  Doner King            3.9              4.2            39
# 1                  Doner King            3.9              4.2            39
# 3                  Doner King            3.9              4.2            39
# 4                  Doner King            3.9              4.2            39
# 5                  Doner King            3.9              4.2            39
# ...                       ...            ...              ...           ...
# 123586  Ariena Boutique Hotel            3.9              4.2            13
# 123594  Ariena Boutique Hotel            3.9              4.2            13
# 123603  Ariena Boutique Hotel            3.9              4.2            13
# 123605  Ariena Boutique Hotel            3.9              4.2            13
# 123635  Ariena Boutique Hotel            3.9              4.2            13
#
# ...

# %%
df.City.value_counts()
# Out:
# City
# Chennai         1691
# Jaipur          1663
# Hyderabad       1646
# Bangalore       1511
# Ahmedabad       1218
# Kolkata         1052
# Kochi            977
# Mumbai           945
# Lucknow          858
# Pune             816
# Raipur           564
# New Delhi        407
# Goa              148
# Magrath Road      20
# Malleshwaram      15
# Banaswadi          6
# Name: count, dtype: int64

# %%
px.pie(names=df.City.value_counts().index[:7], values=df.City.value_counts().values[:7])

# %%
df
# Out:
#               Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0                  Doner King            3.9              4.2            39
# 1                  Doner King            3.9              4.2            39
# 3                  Doner King            3.9              4.2            39
# 4                  Doner King            3.9              4.2            39
# 5                  Doner King            3.9              4.2            39
# ...                       ...            ...              ...           ...
# 123586  Ariena Boutique Hotel            3.9              4.2            13
# 123594  Ariena Boutique Hotel            3.9              4.2            13
# 123603  Ariena Boutique Hotel            3.9              4.2            13
# 123605  Ariena Boutique Hotel            3.9              4.2            13
# 123635  Ariena Boutique Hotel            3.9              4.2            13
#
# ...

# %%
df.columns
# Out:
# Index(['Restaurant Name', 'Dining Rating', 'Delivery Rating', 'Dining Votes',
#        'Delivery Votes', 'Cuisine ', 'Place Name', 'City', 'Item Name',
#        'Best Seller', 'Votes', 'Prices'],
#       dtype='object')

# %%
df.groupby(by='Cuisine ').get_group('Pizza')
# Out:
#               Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 12968        Scoops Ice Cream            3.3              4.4             6
# 12969        Scoops Ice Cream            3.3              4.4             6
# 12973        Scoops Ice Cream            3.3              4.4             6
# 12974        Scoops Ice Cream            3.3              4.4             6
# 12976        Scoops Ice Cream            3.3              4.4             6
# ...                       ...            ...              ...           ...
# 123586  Ariena Boutique Hotel            3.9              4.2            13
# 123594  Ariena Boutique Hotel            3.9              4.2            13
# 123603  Ariena Boutique Hotel            3.9              4.2            13
# 123605  Ariena Boutique Hotel            3.9              4.2            13
# 123635  Ariena Boutique Hotel            3.9              4.2            13
#
# ...

# %%
l=df.groupby(by='Cuisine ')['Votes'].sum().sort_values(ascending=False)

# %%
l
# Out:
# Cuisine
# Beverages        324017
# Desserts         117697
# Fast Food        109034
# Pizza            105728
# North Indian      52965
# Chinese           51320
# Biryani           38161
# Seafood           38149
# South Indian      28656
# Street Food       21424
# Sichuan           21396
# Shake             15425
# Mandi             11613
# Gujarati          10539
# Ice Cream          8069
# Kebab              7918
# Mughlai            6279
# Bakery             5746
# Juices             5486
# Awadhi             5145
# Sandwich           4900
# BBQ                4782
# Rolls              3417
# Kerala             3346
# Andhra             3319
# Maharashtrian      2800
# Pasta              2783
# Burger             2731
# Shawarma           2647
# Hyderabadi         2618
# Wraps              2104
# Continental        1194
# Momos              1033
# Turkish             971
# Rajasthani          770
# Kathiyawadi         668
# Coffee              345
# Tibetan              82
# ...

# %%
px.bar(x=l.index[:10], y=l.values[:10])
